# %%
import pandas as pd
import matplotlib as mp
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
dh = pd.read_csv('../dataset/mh_2010_2012_2014.csv', sep=',')

# %%
da = pd.read_csv('../dataset/TEDSA_5yrs.csv', sep=',')

# %% [markdown]
# <h2>Mental Health Services</h2>

# %%
dh.YEAR.value_counts()
# Out:
# 2012    13807
# 2014    13176
# 2010    10374
# Name: YEAR, dtype: int64

# %%
#group the mental health services data by year and state(LST)
grouped_ys = dh.groupby(['YEAR','LST'], sort=True).agg({'LST': len}).rename(columns={'LST':'NProviders'}).reset_index()
grouped_ys

# %%
#top 10 from 2010
g2010 = grouped_ys.groupby(['YEAR']).get_group(2010).reset_index()[['LST','NProviders']].sort_values(by=['NProviders'], ascending=False).head(10)
g2010
# Out:
#    LST  NProviders
# 4   CA         927
# 35  NY         685
# 39  PA         541
# 15  IL         512
# 36  OH         471
# 9   FL         426
# 23  MI         349
# 45  TX         326
# 20  MA         318
# 16  IN         279

# %%
#function for labeling
def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%d' % int(height),
                ha='center', va='bottom')

# %%
width = 0.50 

fig, ax = plt.subplots()
serv10 = ax.bar(np.arange(10), g2010['NProviders'], width, color='r')

ax.set_xticks(np.arange(10) + width / 2)
ax.set_xticklabels(('CA','NY','PA','IL','OH','FL','MI','TX','MA','IN'))

ax.set_ylabel('Number of hospital/service')
ax.set_xlabel('State')
ax.set_title('States with High MH Services Available in 2010')

autolabel(serv10)
plt.savefig('s2010.jpg')
# Out:
# <img src="data:image/png;base64,...">

# %%
#top 10 from 2012
g2012 = grouped_ys.groupby(['YEAR']).get_group(2012).reset_index()[['LST','NProviders']].sort_values(by=['NProviders'], ascending=False).head(10)
g2012
# Out:
#    LST  NProviders
# 36  NY        1176
# 5   CA         940
# 29  NC         629
# 52  WI         585
# 37  OH         579
# 40  PA         560
# 16  IL         476
# 10  FL         466
# 21  MA         403
# 24  MI         383

# %%
width = 0.50 

fig, ax = plt.subplots()
serv12 = ax.bar(np.arange(10), g2012['NProviders'], width, color='b')
ax.set_xticks(np.arange(10) + width / 2)
ax.set_xticklabels(('NY','CA','NC','WI','OH','PA','IL','FL','MA','MI'))

ax.set_ylabel('Number of hospital/service')
ax.set_xlabel('State')
ax.set_title('States with High MH Services Available in 2012')

autolabel(serv12)
plt.savefig('s2012.jpg')
# Out:
# <img src="data:image/png;base64,...">

# %%
#top 10 from 2014
g2014 = grouped_ys.groupby(['YEAR']).get_group(2014).reset_index()[['LST','NProviders']].sort_values(by=['NProviders'], ascending=False).head(10)
g2014
# Out:
#    LST  NProviders
# 36  NY        1110
# 5   CA         880
# 40  PA         635
# 37  OH         582
# 10  FL         546
# 16  IL         480
# 52  WI         462
# 4   AZ         436
# 29  NC         395
# 24  MI         355

# %%
width = 0.50 

fig, ax = plt.subplots()
serv14 = ax.bar(np.arange(10), g2014['NProviders'], width, color='g')
ax.set_xticks(np.arange(10) + width / 2)
ax.set_xticklabels(('NY','CA','PA','OH','FL','IL','WI','AZ','NC','MI'))

ax.set_ylabel('Number of hospital/service')
ax.set_xlabel('State')
ax.set_title('States with High MH Services Available in 2014')

autolabel(serv14)
plt.savefig('s2014.jpg')
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# <h2>admission</h2>

# %%
ya.head(5)
# Out:
#              Admission
# YEAR STFIPS
# 2010 1           21736
#      2            6952
#      4           28739
#      5           14158
#      6          166587

# %%
grouped_yst = da.groupby(['YEAR','STFIPS'], sort=True).agg({'STFIPS': len}).rename(columns={'STFIPS':'NAdmissions'}).reset_index()

# %%
#top 10 from 2010
a2010 = grouped_yst.groupby(['YEAR']).get_group(2010).reset_index()[['STFIPS','NAdmissions']].sort_values(by=['NAdmissions'], ascending=False).head(10)
a2010
# Out:
#     STFIPS  NAdmissions
# 31      36       311436
# 4        6       166587
# 21      25        90624
# 34      39        87446
# 5        8        79196
# 13      17        73280
# 29      34        71441
# 37      42        62104
# 22      26        61322
# 9       12        61126

# %%
width = 0.50 

fig, ax = plt.subplots()
rects1 = ax.bar(np.arange(10), a2010['NAdmissions'], width, color='r')

ax.set_xticks(np.arange(10) + width / 2)
ax.set_xticklabels(('NY','CA','MA','OH','CO','IL','NJ','PA','MI','FL'))

ax.set_ylabel('Number of admission')
ax.set_xlabel('State')
ax.set_title('States with Highest Admission Rate in 2010')

autolabel(rects1)
plt.savefig('a2010.jpg')
# Out:
# <img src="data:image/png;base64,...">

# %%
data_frame.LST.unique()
# Out:
# array(['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA',
#        'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA',
#        'MS', 'MI', 'MN', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY',
#        'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
#        'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY', 'GU', 'PR', 'VI', 'AS'], dtype=object)

# %%
#top 10 from 2011
a2011 = grouped_yst.groupby(['YEAR']).get_group(2011).reset_index()[['STFIPS','NAdmissions']].sort_values(by=['NAdmissions'], ascending=False).head(10)
a2011
# Out:
#     STFIPS  NAdmissions
# 32      36       304859
# 4        6       159775
# 9       12       104100
# 21      25        88915
# 35      39        82508
# 5        8        77818
# 30      34        73251
# 20      24        65905
# 6        9        62315
# 33      37        62004

# %%
width = 0.50 

fig, ax = plt.subplots()
rects2 = ax.bar(np.arange(10), a2011['NAdmissions'], width, color='y')
ax.set_xticks(np.arange(10) + width / 2)
ax.set_xticklabels(('NY','CA','FL','MA','OH','CO','NJ','MD','CT','NC'))

ax.set_ylabel('Number of admission')
ax.set_xlabel('State')
ax.set_title('States with Highest Admission Rate in 2011')

autolabel(rects2)
plt.savefig('a2011.jpg')
# Out:
# <img src="data:image/png;base64,...">

# %%
#top 10 from 2012
a2012 = grouped_yst.groupby(['YEAR']).get_group(2012).reset_index()[['STFIPS','NAdmissions']].sort_values(by=['NAdmissions'], ascending=False).head(10)
a2012
# Out:
#     STFIPS  NAdmissions
# 32      36       294587
# 4        6       160250
# 21      25        91217
# 5        8        87908
# 30      34        76078
# 35      39        71847
# 9       12        64389
# 20      24        62467
# 6        9        61993
# 33      37        55638

# %%
width = 0.50 

fig, ax = plt.subplots()
rects3 = ax.bar(np.arange(10), a2012['NAdmissions'], width, color='brown')
ax.set_xticks(np.arange(10) + width / 2)
ax.set_xticklabels(('NY','CA','MA','CO','NJ','OH','FL','MD','CT','NC'))

ax.set_ylabel('Number of admission')
ax.set_xlabel('State')
ax.set_title('States with Highest Admission Rate in 2012')

autolabel(rects3)
plt.savefig('a2012.jpg')
# Out:
# <img src="data:image/png;base64,...">

# %%
#top 10 from 2013
a2013 = grouped_yst.groupby(['YEAR']).get_group(2013).reset_index()[['STFIPS','NAdmissions']].sort_values(by=['NAdmissions'], ascending=False).head(10)
a2013
# Out:
#     STFIPS  NAdmissions
# 32      36       285728
# 4        6       156935
# 21      25        94020
# 30      34        88892
# 5        8        86472
# 6        9        64040
# 35      39        55013
# 22      26        54726
# 23      27        53223
# 33      37        52679

# %%
width = 0.50 

fig, ax = plt.subplots()
rects4 = ax.bar(np.arange(10), a2013['NAdmissions'], width, color='pink')
ax.set_xticks(np.arange(10) + width / 2)
ax.set_xticklabels(('NY','CA','MA','NJ','CO','CT','OH','MI','MN','NC'))

ax.set_ylabel('Number of admission')
ax.set_xlabel('State')
ax.set_title('States with Highest Admission Rate in 2013')

autolabel(rects4)
plt.savefig('a2013.jpg')
# Out:
# <img src="data:image/png;base64,...">

# %%
#top 10 from 2014
a2014 = grouped_yst.groupby(['YEAR']).get_group(2014).reset_index()[['STFIPS','NAdmissions']].sort_values(by=['NAdmissions'], ascending=False).head(10)
a2014
# Out:
#     STFIPS  NAdmissions
# 32      36       283785
# 4        6       158831
# 21      25        92789
# 5        8        89855
# 6        9        67129
# 30      34        64370
# 22      26        61080
# 23      27        53459
# 35      39        47026
# 10      13        45108

# %%
width = 0.50 

fig, ax = plt.subplots()
rects5 = ax.bar(np.arange(10), a2014['NAdmissions'], width, color='yellow')
ax.set_xticks(np.arange(10) + width / 2)
ax.set_xticklabels(('NY','CA','MA','CO','CT','NJ','MI','MN','OH','GA'))

ax.set_ylabel('Number of admission')
ax.set_xlabel('State')
ax.set_title('States with Highest Admission Rate in 2014')

autolabel(rects5)
plt.savefig('a2014.jpg')
# Out:
# <img src="data:image/png;base64,...">

# %%
joined = pd.merge(a2010, a2011, on='STFIPS')
joined = pd.merge(joined, a2012, on='STFIPS')
joined = pd.merge(joined, a2013, on='STFIPS')
joined = pd.merge(joined, a2014, on='STFIPS')

joined.columns = ['STFIPS', 'y2010', 'y2011', 'y2012', 'y2013', 'y2014']

joined
# Out:
#    STFIPS   y2010   y2011   y2012   y2013   y2014
# 0      36  311436  304859  294587  285728  283785
# 1       6  166587  159775  160250  156935  158831
# 2      25   90624   88915   91217   94020   92789
# 3      39   87446   82508   71847   55013   47026
# 4       8   79196   77818   87908   86472   89855
# 5      34   71441   73251   76078   88892   64370

# %%
width = 0.15 
ind = np.arange(6)

fig, ax = plt.subplots()
y2010 = ax.bar(ind, joined['y2010'], width, color='r')
y2011 = ax.bar(ind+width, joined['y2011'], width, color='y')
y2012 = ax.bar(ind+2*width, joined['y2012'], width, color='brown')
y2013 = ax.bar(ind+3*width, joined['y2013'], width, color='pink')
y2014 = ax.bar(ind+4*width, joined['y2014'], width, color='yellow')

ax.set_title('States with Highest Admission Rate 2010-2014')
ax.set_xlabel('State')
ax.set_ylabel('Number of admission')

ax.set_xticks(ind+4*width / 2)
ax.set_xticklabels(('New York', 'California', 'Massachusetts', 'Ohio', 'Colorado', 'New Jersey'))

ax.legend((y2010[0], y2011[0], y2012[0], y2013[0], y2014[0]), ('2010', '2011', '2012', '2013', '2014'))
ax.grid(True)

plt.savefig('Top6 admission.jpg')
# Out:
# <img src="data:image/png;base64,...">
