# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('c:/Users/Raghav.sharma/Desktop/train.csv')

# %%
df1=pd.read_csv('c:/Users/Raghav.sharma/Desktop/validation.csv')

df3=df.append(df1)

# %%
df3.columns
# Out:
# Index([u'Unnamed: 0', u'AGE', u'GENDER', u'RACE', u'ETHNIC', u'MARSTAT',
#        u'EDUC', u'EMPLOY', u'DETNLF', u'PREG', u'VET', u'LIVARAG', u'ARRESTS',
#        u'SERVSETA', u'PSOURCE', u'DETCRIM', u'NOPRIOR', u'SUB1', u'ROUTE1',
#        u'FREQ1', u'FRSTUSE1', u'SUB2', u'SUB3', u'NUMSUBS', u'IDU', u'DSMCRIT',
#        u'PSYPROB'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index([u'Unnamed: 0', u'AGE', u'GENDER', u'RACE', u'ETHNIC', u'MARSTAT',
#        u'EDUC', u'EMPLOY', u'DETNLF', u'PREG', u'VET', u'LIVARAG', u'ARRESTS',
#        u'SERVSETA', u'PSOURCE', u'DETCRIM', u'NOPRIOR', u'SUB1', u'ROUTE1',
#        u'FREQ1', u'FRSTUSE1', u'SUB2', u'SUB3', u'NUMSUBS', u'IDU', u'DSMCRIT',
#        u'PSYPROB'],
#       dtype='object')

# %%
df3.corr()
# Out:
#             Unnamed: 0       AGE    GENDER      RACE    ETHNIC   MARSTAT  \
# Unnamed: 0    1.000000  0.045299  0.001543  0.014607 -0.015990  0.004404
# AGE           0.045299  1.000000 -0.039520 -0.097534  0.041567  0.430614
# GENDER        0.001543 -0.039520  1.000000 -0.014709  0.042973  0.070394
# RACE          0.014607 -0.097534 -0.014709  1.000000 -0.264006 -0.027051
# ETHNIC       -0.015990  0.041567  0.042973 -0.264006  1.000000  0.013934
# MARSTAT       0.004404  0.430614  0.070394 -0.027051  0.013934  1.000000
# EDUC          0.047292  0.217261  0.037403 -0.049098  0.064533  0.122646
# EMPLOY       -0.028417 -0.023130  0.098303  0.011028  0.009404 -0.015162
# DETNLF       -0.035128  0.034107  0.036547  0.024564  0.003468  0.010355
# PREG         -0.000590  0.065008 -0.162860  0.006028 -0.009036  0.020686
# VET          -0.018072 -0.142581  0.100527  0.016705  0.011120 -0.094343
# LIVARAG      -0.028761 -0.012497  0.055355 -0.017609  0.049840  0.029045
# ...

# %%
df=df3
df.shape
# Out:
# (1356734, 27)

# %%
sns.countplot("SUB2",data=df1)
plt.show()

# %%
sns.countplot("SUB2",data=df)
plt.show()

# %%
X_train = df.drop(["SUB2","SUB3","Unnamed: 0","NUMSUBS"], axis=1)
Y_train = df["SUB2"]

# %%
X_validate = df1.drop(["SUB2","Unnamed: 0","SUB3","NUMSUBS"], axis=1)
Y_validate = df1["SUB2"]

# %%
X_train.shape
# Out:
# (1356734, 23)

# %%
# Out:
# <1002927x174 sparse matrix of type '<type 'numpy.float64'>'
# 	with 25073175 stored elements in Compressed Sparse Row format>

# %%
from sklearn.preprocessing import OneHotEncoder
ohe=OneHotEncoder()
ohe.fit(X_train)
X_train1=ohe.transform(X_train)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
logreg = LogisticRegression()
logreg.fit(X_train1, Y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
prediction = logreg.predict(X_validate1)
print('The accuracy of the Logistic Regression is',metrics.accuracy_score(prediction,Y_validate))
# Out:
# ('The accuracy of the Logistic Regression is', 0.78817622002775867)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

rfc = RandomForestClassifier()
rfc.fit(X_train1, Y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)

# %%
prediction = rfc.predict(X_validate1)
print('The accuracy of the Random Forest Classification is',metrics.accuracy_score(prediction,Y_validate))
# Out:
# ('The accuracy of the Random Forest Classification is', 0.79321745927923037)

# %%
dtc = DecisionTreeClassifier()
dtc.fit(X_train1, Y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
prediction = rfc.predict(X_validate1)
print('The accuracy of the Random Forest Classification is',metrics.accuracy_score(prediction,Y_validate))

# %%
prediction = dtc.predict(X_validate1)
print('The accuracy of the Decision Tree Classifier is',metrics.accuracy_score(prediction,Y_validate))
# Out:
# ('The accuracy of the Decision Tree Classifier is', 0.74255779078857109)

# %%
from sklearn.cross_validation import KFold, cross_val_score
k_fold = KFold(len(Y_train), n_folds=5, shuffle=True, random_state=0)
clf = LogisticRegression()
print cross_val_score(clf, X_train1, Y_train, cv=k_fold, n_jobs=1)
# Out:
# [ 0.49132292  0.49116814  0.49102072  0.48975666  0.49104833]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.cross_validation import KFold, cross_val_score
k_fold = KFold(len(Y_train), n_folds=5, shuffle=True, random_state=0)
clf = RandomForestClassifier()
print cross_val_score(clf, X_train1, Y_train, cv=k_fold, n_jobs=1)
# Out:
# C:\Users\raghav.sharma\AppData\Local\Continuum\Anaconda2\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
from sklearn.cross_validation import KFold, cross_val_score
k_fold = KFold(len(Y_train), n_folds=5, shuffle=True, random_state=0)
clf = DecisionTreeClassifier()
print cross_val_score(clf, X_train1, Y_train, cv=k_fold, n_jobs=1)
# Out:
# [ 0.43118221  0.43135911  0.43061836  0.43094267  0.43013717]

# %%
df3=df.append(df1)

# %%
X_train = df3.drop(["SUB2","Unnamed: 0"], axis=1)
Y_train = df3["SUB2"]

# %%
X_train.shape
# Out:
# (1253659, 25)

# %%
Y_train.shape
# Out:
# (1253659L,)

# %%
from sklearn.preprocessing import OneHotEncoder
ohe=OneHotEncoder()
ohe.fit(X_train)
X_train1=ohe.transform(X_train)

# %%
X_train1.shape
# Out:
# (1253659, 174)

# %%
from xgboost import XGBRegressor
k_fold = KFold(len(Y_train), n_folds=5, shuffle=True, random_state=0)
clf = XGBRegressor()
print cross_val_score(clf, X_train1, Y_train, cv=k_fold, n_jobs=1)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-184-58ab6edad304> in <module>()
# ----> 1 from xgboost import XGBRegressor
#       2 k_fold = KFold(len(Y_train), n_folds=5, shuffle=True, random_state=0)
#       3 clf = XGBRegressor()
#       4 print cross_val_score(clf, X_train1, Y_train, cv=k_fold, n_jobs=1)
#
# ImportError: No module named xgboost

# %%
from xgboost import XGBRegressor

my_model = XGBRegressor()
# Add silent=True to avoid printing out updates with each cycle
my_model.fit(train_X, train_y, verbose=False)

# %%
    # here the model means the model 
    # data is used for the data 
    #prediction_input means the inputs used for prediction
    # output mean the value which are to be predicted
    # here we will try to find out the Accuarcy of model by using same data for fiiting and 
    #comparison for same data
    #Fit the model:
    model.fit(data[prediction_input],data[output]) #Here we fit the model using training set
  
    #Make predictions on training set:
    predictions = model.predict(data[prediction_input])
  
    #Print accuracy
    # now checkin accuracy for same data
    accuracy = metrics.accuracy_score(predictions,data[output])
    print("Accuracy : %s" % "{0:.3%}".format(accuracy))
 
    
    kf = KFold(data.shape[0], n_folds=5)
    # About cross validitaion please follow this link
    #https://www.analyticsvidhya.com/blog/2015/11/improve-model-performance-cross-validation-in-python-r/
    #let me explain a little bit data.shape[0] means number of rows in data
    #n_folds is for number of folds
    error = []
    for train, test in kf:
        # as the data is divided into train and test using KFold
        # now as explained above we have fit many models 
        # so here also we are going to fit model
        #in the cross validation the data in train and test will change for evry iteration
        train_X = (data[prediction_input].iloc[train,:])# in this iloc is used for index of trainig data
        # here iloc[train,:] means all row in train in kf amd the all columns
        train_y = data[output].iloc[train]# here is only column so it repersenting only row in train
        # Training the algorithm using the predictors and target.
        model.fit(train_X, train_y)
    
        # now do this for test data also
        test_X=data[prediction_input].iloc[test,:]
        test_y=data[output].iloc[test]
        error.append(model.score(test_X,test_y))
        # printing the score 
        print("Cross-Validation Score : %s" % "{0:.3%}".format(np.mean(error)))

# %%
model = DecisionTreeClassifier()
prediction_var = ['radius_mean','perimeter_mean','area_mean','compactness_mean','concave points_mean']
outcome_var= "SUB2"
classification_model(model,data,prediction_var,outcome_var)

# %%
df1[df1<0]=0
# Out:
# C:\Users\raghav.sharma\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df1['SUB3'] = np.where(df1['SUB2']==1, 1, 0)
# Out:
# C:\Users\raghav.sharma\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df1
# Out:
#           AGE  GENDER  RACE  ETHNIC  EDUC  EMPLOY  LIVARAG  ARRESTS  STFIPS  \
# 0         8.0     1.0   5.0     5.0   3.0     4.0      3.0      0.0    29.0
# 1         9.0     1.0   5.0     5.0   3.0     3.0      3.0      0.0    26.0
# 2         5.0     1.0   5.0     5.0   5.0     4.0      2.0      0.0    17.0
# 3         8.0     1.0   4.0     5.0   2.0     4.0      2.0      1.0    17.0
# 4         7.0     2.0   5.0     5.0   3.0     2.0      3.0      0.0    19.0
# 5         2.0     1.0  21.0     2.0   1.0     4.0      2.0      0.0    19.0
# 6         9.0     2.0   5.0     4.0   5.0     1.0      3.0      0.0    17.0
# 7         5.0     1.0   5.0     5.0   3.0     3.0      3.0      1.0    39.0
# 8         8.0     1.0   5.0     5.0   3.0     1.0      1.0      2.0    55.0
# 9         6.0     2.0   5.0     5.0   4.0     3.0      3.0      0.0    39.0
# 10        6.0     2.0   5.0     5.0   4.0     4.0      3.0      0.0    29.0
# ...

# %%
df1.lt(0).sum()
# Out:
# AGE        0
# GENDER     0
# RACE       0
# ETHNIC     0
# EDUC       0
# EMPLOY     0
# LIVARAG    0
# ARRESTS    0
# STFIPS     0
# SUB1       0
# SUB2       0
# NUMSUBS    0
# DSMCRIT    0
# dtype: int64

# %%
corr = df1.corr() # .corr is used for find corelation
plt.figure(figsize=(14,14))
sns.heatmap(corr, cbar = True,  square = True, annot=True, fmt= '.2f',annot_kws={'size': 15},
           xticklabels=' features_mean', yticklabels= 'features_mean',
           cmap= 'coolwarm')
plt.show()

# %%
df1
# Out:
#           AGE  GENDER  RACE  ETHNIC  EDUC  EMPLOY  LIVARAG  ARRESTS  STFIPS  \
# 0         8.0     1.0   5.0     5.0   3.0     4.0      3.0      0.0    29.0
# 1         9.0     1.0   5.0     5.0   3.0     3.0      3.0      0.0    26.0
# 2         5.0     1.0   5.0     5.0   5.0     4.0      2.0      0.0    17.0
# 3         8.0     1.0   4.0     5.0   2.0     4.0      2.0      1.0    17.0
# 4         7.0     2.0   5.0     5.0   3.0     2.0      3.0      0.0    19.0
# 5         2.0     1.0  21.0     2.0   1.0     4.0      2.0      0.0    19.0
# 6         9.0     2.0   5.0     4.0   5.0     1.0      3.0      0.0    17.0
# 7         5.0     1.0   5.0     5.0   3.0     3.0      3.0      1.0    39.0
# 8         8.0     1.0   5.0     5.0   3.0     1.0      1.0      2.0    55.0
# 9         6.0     2.0   5.0     5.0   4.0     3.0      3.0      0.0    39.0
# 10        6.0     2.0   5.0     5.0   4.0     4.0      3.0      0.0    29.0
# ...

# %%
X_train = train.drop("SUB3", axis=1)
Y_train = train["SUB3"]

# %%
X_validate = validate.drop("SUB3", axis=1)
Y_validate = validate["SUB3"]

# %%
df1.GENDER.value_counts()
# Out:
# 1.0    4348410
# 2.0    2093978
# 0.0       1146
# Name: GENDER, dtype: int64

# %%
train.shape
# Out:
# (3866120, 14)

# %%
X_validate.shape
# Out:
# (1288707, 12)

# %%
from sklearn.preprocessing import OneHotEncoder
ohe=OneHotEncoder()
ohe.fit(X_train)
X_train1=ohe.transform(X_train)

# %%
from sklearn.preprocessing import OneHotEncoder
ohe=OneHotEncoder()
ohe.fit(X_validate)
X_validate1=ohe.transform(X_validate)

# %%
X_validate1.shape
# Out:
# (1288707, 146)

# %%
X_train1.shape
# Out:
# (3866120, 146)

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.ensemble import RandomForestClassifier

logreg = LogisticRegression()
logreg.fit(X_train1, Y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
featimp = pd.Series(model.feature_importances_, index=prediction_var).sort_values(ascending=False)
print(featimp) 


important features

# %%
pd.scatter_matrix(df1, c=colors, alpha = 0.5, figsize = (15, 15))

# %%
# As we are going to use many models lets make a function
# Which we can use with different models
def classification_model(model,data,prediction_input,output):
    # here the model means the model 
    # data is used for the data 
    #prediction_input means the inputs used for prediction
    # output mean the value which are to be predicted
    # here we will try to find out the Accuarcy of model by using same data for fiiting and 
    #comparison for same data
    #Fit the model:
    model.fit(X_train1,X_validate1) #Here we fit the model using training set
  
    #Make predictions on training set:
    predictions = model.predict(data[prediction_input])
  
    #Print accuracy
    # now checkin accuracy for same data
    accuracy = metrics.accuracy_score(predictions,data[output])
    print("Accuracy : %s" % "{0:.3%}".format(accuracy))
 
    
    kf = KFold(data.shape[0], n_folds=5)
    # About cross validitaion please follow this link
    #https://www.analyticsvidhya.com/blog/2015/11/improve-model-performance-cross-validation-in-python-r/
    #let me explain a little bit data.shape[0] means number of rows in data
    #n_folds is for number of folds
    error = []
    for train, test in kf:
        # as the data is divided into train and test using KFold
        # now as explained above we have fit many models 
        # so here also we are going to fit model
        #in the cross validation the data in train and test will change for evry iteration
        train_X = (data[prediction_input].iloc[train,:])# in this iloc is used for index of trainig data
        # here iloc[train,:] means all row in train in kf amd the all columns
        train_y = data[output].iloc[train]# here is only column so it repersenting only row in train
        # Training the algorithm using the predictors and target.
        model.fit(train_X, train_y)
    
        # now do this for test data also
        test_X=data[prediction_input].iloc[test,:]
        test_y=data[output].iloc[test]
        error.append(model.score(test_X,test_y))
        # printing the score 
        print("Cross-Validation Score : %s" % "{0:.3%}".format(np.mean(error)))

# %%
df2=validate_df[['AGE','ALCDRUG','ARRESTS','DETCRIM','DETNLF','DSMCRIT','EDUC','EMPLOY',
       'ETHNIC','FREQ1', 'FREQ2','FRSTUSE1','FRSTUSE2','GENDER']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-1d24937ddaae> in <module>()
#       1 df2=validate_df[['AGE','ALCDRUG','ARRESTS','DETCRIM','DETNLF','DSMCRIT','EDUC','EMPLOY',
# ----> 2        'ETHNIC','FREQ1', 'FREQ2','FRSTUSE1','FRSTUSE2','GENDER']]
#
# C:\Users\raghav.sharma\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    2054         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2055             # either boolean or fancy integer index
# -> 2056             return self._getitem_array(key)
#    2057         elif isinstance(key, DataFrame):
#    2058             return self._getitem_frame(key)
#
# C:\Users\raghav.sharma\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _getitem_array(self, key)
# ...

# %%
logreg = LogisticRegression()
logreg.fit(X_train1, Y_train)
from sklearn import metrics
prediction4=logreg.predict(X_validate1)
print('The accuracy of the Logistic Regression is',metrics.accuracy_score(prediction4,Y_validate1))

# %%
correlation = df1.corr()
plt.figure(figsize=(30,30))
sns.heatmap(correlation, vmax=1, square=True,annot=True,cmap='cubehelix')

plt.title('Correlation between different fearures')
plt.show()

# %%
# Correlation tells relation between two attributes.
# Correlation requires continous data. Hence, ignore categorical data

cols=df1.columns 
# Calculates pearson co-efficient for all combinations
data_corr = df.corr()
size = 34
# Set the threshold to select only highly correlated attributes
threshold = 0.5

# List of pairs along with correlation above threshold
corr_list = []

#Search for the highly correlated pairs
for i in range(0,size): #for 'size' features
    for j in range(i+1,size): #avoid repetition
        if (data_corr.iloc[i,j] >= threshold and data_corr.iloc[i,j] < 1) or (data_corr.iloc[i,j] < 0 and data_corr.iloc[i,j] <= -threshold):
            corr_list.append([data_corr.iloc[i,j],i,j]) #store correlation and columns index

#Sort to show higher ones first            
s_corr_list = sorted(corr_list,key=lambda x: -abs(x[0]))

#Print correlations and column names
for v,i,j in s_corr_list:
    print ("%s and %s = %.2f" % (cols[i],cols[j],v))
# Out:
# AGE and GENDER = 0.97
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-88-2965f8788409> in <module>()
#      23 #Print correlations and column names
#      24 for v,i,j in s_corr_list:
# ---> 25     print ("%s and %s = %.2f" % (cols[i],cols[j],v))
#
# C:\Users\raghav.sharma\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\indexes\base.pyc in __getitem__(self, key)
#    1637
#    1638         if is_scalar(key):
# -> 1639             return getitem(key)
#    1640
#    1641         if isinstance(key, slice):
#
# IndexError: index 13 is out of bounds for axis 0 with size 4

# %%
df1
# Out:
#          AGE  GENDER  SUB2
# 0         10       2     2
# 1          6       1     4
# 2         10       1     1
# 3          7       1     7
# 4          7       2     3
# 5          7       1     4
# 6          7       1    10
# 7          7       2     7
# 8          8       2     7
# 9          7       1     1
# 10        11       1     1
# 11        10       1     1
# 12        10       1     1
# 13        10       2     7
# 14        11       1     1
# 15        11       1     1
# 16         8       1     1
# 17         8       1    13
# 18         6       1     7
# 19         9       2     5
# 20         7       1     1
# 21         9       2     1
# 22        11       1     1
# 23         9       2     1
# 24         6       1     7
# 25         8       2     4
# 26         9       1     4
# 27         9       1     1
# 28         8       1     1
# 29         5       1     1
# ...      ...     ...   ...
# 1929941    6       1     4
# 1929942    7       1     1
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
X_train = df1.drop("SUB2", axis=1)
Y_train = df1["SUB2"]
logreg = RandomForestClassifier()
logreg.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)

# %%
Y_train
# Out:
# 0          3
# 1          4
# 2         10
# 3          1
# 4          1
# 5          2
# 6          1
# 7          2
# 8         10
# 9          3
# 10         3
# 11         1
# 12         1
# 13         4
# 14        10
# 15        13
# 16         4
# 17         2
# 18         1
# 19         4
# 20        13
# 21         1
# 22         3
# 23         1
# 24         1
# 25         7
# 26         4
# 27         3
# 28         4
# 29         2
#           ..
# 643294     2
# 643295     3
# 643296     4
# 643297     3
# 643298     1
# 643299     1
# 643300     1
# 643301     2
# 643302     3
# 643303     3
# 643304     1
# 643305     2
# 643306     1
# 643307     1
# 643308    10
# 643309     1
# 643310     7
# 643311     1
# 643312     2
# 643313     1
# 643314    10
# 643315     3
# 643316     4
# 643317     6
# 643318     3
# 643319     4
# 643320     2
# 643321     4
# 643322     1
# 643323     1
# Name: SUB2, Length: 643324, dtype: int64

# %%
validate_df=pd.read_csv('c:/Users/Raghav.sharma/Desktop/dmLab/validatewDSM.csv')

# %%
df1= validate_df[['AGE','SUB1','SUB2','ALCFLG','COKEFLG','MARFLG','HERFLG','METHFLG']]

# %%
X_validate1= df1.drop("SUB2", axis=1)
Y_validate1=  df1["SUB2"]

# %%
X_validate1
# Out:
#         AGE  GENDER
# 0        10       1
# 1        12       2
# 2         5       1
# 3         5       2
# 4         9       1
# 5         2       2
# 6         7       1
# 7        12       2
# 8        12       2
# 9        10       1
# 10       12       2
# 11        6       1
# 12       10       1
# 13        5       1
# 14        3       1
# 15        8       2
# 16       11       1
# 17        9       2
# 18        6       1
# 19       11       2
# 20        5       1
# 21        9       1
# 22        9       1
# 23        7       1
# 24        4       1
# 25        5       2
# 26       11       1
# 27       10       1
# 28        5       1
# 29       11       1
# ...     ...     ...
# 643294    4       1
# 643295    3       2
# 643296    5       2
# 643297    7       1
# 643298   10       1
# 643299   11       1
# 643300    2       1
# 643301    7       2
# 643302    9       2
# 643303   10       2
# 643304   10       1
# 643305   10       1
# 643306    7       2
# ...

# %%
from sklearn import metrics
prediction4=logreg.predict(X_validate1)
print('The accuracy of the Logistic Regression is',metrics.accuracy_score(prediction4,Y_validate1))
# Out:
# ('The accuracy of the Logistic Regression is', 0.81190348875527729)

# %%
# Out:
# C:\Users\raghav.sharma\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\ops.py:798: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = getattr(x, name)(y)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-2631b60d1e7c> in <module>()
# ----> 1 df1=df[df['SUB1']=='4']
#
# C:\Users\raghav.sharma\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\ops.pyc in wrapper(self, other, axis)
#     859
#     860             with np.errstate(all='ignore'):
# --> 861                 res = na_op(values, other)
#     862             if is_scalar(res):
#     863                 raise TypeError('Could not compare %s type with Series' %
#
# C:\Users\raghav.sharma\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\ops.pyc in na_op(x, y)
# ...

# %% [markdown]
# AS LAST TYM WE HAVE SEEN THAT ALCOHOL IS IN LARGER QUANTITY AS COMPARED TO OTHER STATES:
#
#
# #TRY TO FIND  STATES  WHERE OTHER SUBASTANCE  IS GReaTER AMOUNT THAN ALOCHOL
#
#
#
# MARIJUANA>
#
# df1=df[df['STFIPS']==39]
# df1.SUB1.value_counts()

# %%
q
